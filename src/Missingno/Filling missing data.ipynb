# %%
import pandas as pd
import missingno as msno

# %%
tree_census = pd.read_csv('../../datasets/2015StreetTreesCensus_TREES.csv')
tree_census_subset = tree_census[['tree_id','tree_dbh',
       'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
       'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
       'brnch_ligh', 'brnch_shoe', 'brnch_othe']]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# Matrix Chart
msno.matrix(tree_census_subset)
# Out:
# <AxesSubplot:>

# %%
tree_census_subset.isnull().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# spc_common    31619
# steward       31615
# guards        31616
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trnk_wire         0
# trnk_light        0
# trnk_other        0
# brnch_ligh        0
# brnch_shoe        0
# brnch_othe        0
# dtype: int64

# %%
# filter all the columns that have at least one missing value
tree_census_subset[tree_census_subset.isnull().any(axis=1)]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 61       194505         2           0          OnCurb   Dead    NaN       NaN
# 307      208525         0           9          OnCurb  Stump    NaN       NaN
# 370      220914         4           0          OnCurb   Dead    NaN       NaN
# 494      176343         0          17          OnCurb  Stump    NaN       NaN
# 556      179963         2           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683691   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683693   170888         0           5          OnCurb  Stump    NaN       NaN
# 683695   177922         0          17          OnCurb  Stump    NaN       NaN
# 683696   193791         3           0          OnCurb   Dead    NaN       NaN
# 683697   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %% [markdown]
# ## Drop Missing Data

# %%
# Drop rows containing NaN
tree_census_subset.dropna()
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# Drop columns containing NaN
tree_census_subset.dropna(axis=1)
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status         user_type  \
# 0        180683         3           0   OnCurb  Alive  TreesCount Staff
# 1        200540        21           0   OnCurb  Alive  TreesCount Staff
# 2        204026         3           0   OnCurb  Alive         Volunteer
# 3        204337        10           0   OnCurb  Alive         Volunteer
# 4        189565        21           0   OnCurb  Alive         Volunteer
# ...         ...       ...         ...      ...    ...               ...
# 683783   155433        25           0   OnCurb  Alive         Volunteer
# 683784   183795         7           0   OnCurb  Alive         Volunteer
# 683785   166161        12           0   OnCurb  Alive         Volunteer
# 683786   184028         9           0   OnCurb  Alive  TreesCount Staff
# 683787   200607        23           0   OnCurb  Alive  TreesCount Staff
#
#        root_stone root_grate root_other trnk_wire trnk_light trnk_other  \
# ...

# %% [markdown]
# ## Fill the Nans

# %%
# Fill wiuth a fixed value
tree_census_subset.fillna("No Observations") # or a number
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# Fill Forward
tree_census_subset.fillna(method='ffill') # it fills the missing values with the previous value
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# Fill Backward
tree_census_subset.fillna(method='bfill') # it fills the missing values with the next value
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# Interpolate values
tree_census_subset.interpolate(method='linear') # it fills the missing values with the average of the previous and next value
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
# Fill with mean
tree_census_subset.fillna(value=tree_census_subset.mean())

# %%
tree_census_subset.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aky\Documents\Programs\EDA\src\Missingno\Filling missing data.ipynb Cell 15 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aky/Documents/Programs/EDA/src/Missingno/Filling%20missing%20data.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> tree_census_subset.describe()
#
# NameError: name 'tree_census_subset' is not defined
