# %%
import pandas as pd

pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
tree_census = pd.read_csv('../../datasets/2015StreetTreesCensus_TREES.csv')
tree_census
# Out:
#         created_at  tree_id  block_id  \
# 0       08/27/2015   180683    348711
# 1       09/03/2015   200540    315986
# 2       09/05/2015   204026    218365
# 3       09/05/2015   204337    217969
# 4       08/30/2015   189565    223043
# ...            ...      ...       ...
# 683783  08/18/2015   155433    217978
# 683784  08/29/2015   183795    348185
# 683785  08/22/2015   166161    401670
# 683786  08/29/2015   184028    504204
# 683787  09/03/2015   200607    306527
#
#                                              the_geom  tree_dbh  stump_diam  \
# 0       POINT (-73.84421521958048 40.723091773924274)         3           0
# 1        POINT (-73.81867945834878 40.79411066708779)        21           0
# 2       POINT (-73.93660770459083 40.717580740099116)         3           0
# 3       POINT (-73.93445615919741 40.713537494833226)        10           0
# 4        POINT (-73.97597938483258 40.66677775537875)        21           0
# ...

# %%
tree_census.columns
# Out:
# Index(['created_at', 'tree_id', 'block_id', 'the_geom', 'tree_dbh',
#        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
#        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
#        'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address', 'zipcode',
#        'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist', 'st_assem',
#        'st_senate', 'nta', 'nta_name', 'boro_ct', 'state', 'Latitude',
#        'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id','tree_dbh',
       'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
       'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
       'brnch_ligh', 'brnch_shoe', 'brnch_othe']]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# spc_common    31619
# steward       31615
# guards        31616
# sidewalk      31616
# user_type         0
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trnk_wire         0
# trnk_light        0
# trnk_other        0
# brnch_ligh        0
# brnch_shoe        0
# brnch_othe        0
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 61       194505         2           0          OnCurb   Dead    NaN       NaN
# 307      208525         0           9          OnCurb  Stump    NaN       NaN
# 370      220914         4           0          OnCurb   Dead    NaN       NaN
# 494      176343         0          17          OnCurb  Stump    NaN       NaN
# 556      179963         2           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683691   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683693   170888         0           5          OnCurb  Stump    NaN       NaN
# 683695   177922         0          17          OnCurb  Stump    NaN       NaN
# 683696   193791         3           0          OnCurb   Dead    NaN       NaN
# 683697   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# spc_common    object
# steward       object
# guards        object
# sidewalk      object
# user_type     object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trnk_wire     object
# trnk_light    object
# trnk_other    object
# brnch_ligh    object
# brnch_shoe    object
# brnch_othe    object
# dtype: object

# %%
tree_census_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
big_trees = tree_census_subset[tree_census_subset['tree_dbh'] > 50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2385     168583       425           0          OnCurb  Alive   Good
# 3724     199546        51           0          OnCurb  Alive   Good
# 4874     139665        72           0  OffsetFromCurb  Alive   Good
# 6711     209349       122           0          OnCurb  Alive   Good
# 10053    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675215   179496        52           0  OffsetFromCurb  Alive   Good
# 677926   166796        54           0          OnCurb  Alive   Good
# 679860   169501        51           0          OnCurb  Alive   Good
# 681711   179366       281           0          OnCurb  Alive   Fair
# 682784   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin       spc_common steward guards  \
# ...

# %%
big_trees[['tree_id','tree_dbh','spc_common']].plot(kind='scatter', x='tree_id', y='tree_dbh', alpha=0.8, figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
big_trees = tree_census_subset[tree_census_subset['stump_diam'] > 50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6101     200925         0          52   OnCurb  Stump    NaN       NaN
# 6161     200924         0          55   OnCurb  Stump    NaN       NaN
# 6454     166008         0          72   OnCurb  Stump    NaN       NaN
# 7028     206818         0         100   OnCurb  Stump    NaN       NaN
# 9836     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 642174   130476         0          53   OnCurb  Stump    NaN       NaN
# 645950   135904         0          65   OnCurb  Stump    NaN       NaN
# 649133   154188         0          65   OnCurb  Stump    NaN       NaN
# 652618   154181         0          60   OnCurb  Stump    NaN       NaN
# 653006   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        spc_common steward guards sidewalk         user_type problems  \
# ...

# %%
big_trees[['tree_id','stump_diam']].plot(kind='scatter', x='tree_id', y='stump_diam', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %%
#tree_census_subset['spc_latin'].value_counts()
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
tree_census_subset['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
stumps = tree_census_subset[tree_census_subset['status'] == 'Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 307      208525         0           9          OnCurb  Stump    NaN       NaN
# 494      176343         0          17          OnCurb  Stump    NaN       NaN
# 598      239221         0          16          OnCurb  Stump    NaN       NaN
# 619      208246         0           6  OffsetFromCurb  Stump    NaN       NaN
# 640      179766         0          30          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683343   152836         0          13          OnCurb  Stump    NaN       NaN
# 683684   191219         0          25          OnCurb  Stump    NaN       NaN
# 683693   170888         0           5          OnCurb  Stump    NaN       NaN
# 683695   177922         0          17          OnCurb  Stump    NaN       NaN
# 683697   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
dead = tree_census_subset[tree_census_subset['status'] == 'Dead']
dead
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 61       194505         2           0          OnCurb   Dead    NaN       NaN
# 370      220914         4           0          OnCurb   Dead    NaN       NaN
# 556      179963         2           0          OnCurb   Dead    NaN       NaN
# 639      192569         2           0          OnCurb   Dead    NaN       NaN
# 644      184295         0           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682819   155430         2           0          OnCurb   Dead    NaN       NaN
# 682971   206961         5           0          OnCurb   Dead    NaN       NaN
# 683341   156566        10           0          OnCurb   Dead    NaN       NaN
# 683691   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683696   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %%
tree_census_subset.columns
# Out:
# Index(['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
#        'spc_latin', 'spc_common', 'steward', 'guards', 'sidewalk', 'user_type',
#        'problems', 'root_stone', 'root_grate', 'root_other', 'trnk_wire',
#        'trnk_light', 'trnk_other', 'brnch_ligh', 'brnch_shoe', 'brnch_othe'],
#       dtype='object')

# %%
tree_problems = tree_census_subset[['root_stone', 'root_grate', 'root_other', 'trnk_wire',
       'trnk_light', 'trnk_other', 'brnch_ligh', 'brnch_shoe', 'brnch_othe']]
tree_problems
# Out:
#        root_stone root_grate root_other trnk_wire trnk_light trnk_other  \
# 0              No         No         No        No         No         No
# 1             Yes         No         No        No         No         No
# 2              No         No         No        No         No         No
# 3             Yes         No         No        No         No         No
# 4             Yes         No         No        No         No         No
# ...           ...        ...        ...       ...        ...        ...
# 683783         No         No         No        No         No         No
# 683784         No         No         No        No         No         No
# 683785         No         No         No        No         No         No
# 683786         No         No         No        No         No         No
# 683787         No         No         No        No         No         No
#
#        brnch_ligh brnch_shoe brnch_othe
# 0              No         No         No
# ...

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trnk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466     670514      682757      651215
# Yes      139999        3536       30322      13274        1031       32573
#
#      brnch_ligh  brnch_shoe  brnch_othe
# No       621423      683377      659433
# Yes       62365         411       24355
